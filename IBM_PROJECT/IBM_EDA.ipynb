# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sqlite3

# %%
# %load_ext sql

# %%
# %sql sqlite:///attr_data.db

# %%
# %%sql
# .schema attrition_records
# Out:
#  * sqlite:///attr_data.db
# (sqlite3.OperationalError) near ".": syntax error
# [SQL: .schema attrition_records]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# %%sql
#
# PRAGMA table_info(attrition_records);
# Out:
#  * sqlite:///attr_data.db
# Done.
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'Age', 'INT', 0, None, 0),
#  (2, 'Attrition', 'TEXT', 0, None, 0),
#  (3, 'BusinessTravel', 'TEXT', 0, None, 0),
#  (4, 'DailyRate', 'INT', 0, None, 0),
#  (5, 'Department', 'TEXT', 0, None, 0),
#  (6, 'DistanceFromHome', 'INT', 0, None, 0),
#  (7, 'Education', 'INT', 0, None, 0),
#  (8, 'EducationField', 'TEXT', 0, None, 0),
#  (9, 'EmployeeCount', 'INT', 0, None, 0),
#  (10, 'EmployeeNumber', 'INT', 0, None, 0),
#  (11, 'EnvironmentSatisfaction', '', 0, None, 0),
#  (12, 'Gender', 'TEXT', 0, None, 0),
#  (13, 'HourlyRate', 'INT', 0, None, 0),
#  (14, 'JobInvolvement', 'INT', 0, None, 0),
#  (15, 'JobLevel', 'INT', 0, None, 0),
#  (16, 'JobRole', 'TEXT', 0, None, 0),
#  (17, 'JobSatisfaction', 'INT', 0, None, 0),
#  (18, 'MaritalStatus', 'TEXT', 0, None, 0),
#  (19, 'MonthlyIncome', 'INT', 0, None, 0),
#  (20, 'MonthlyRate', 'INT', 0, None, 0),
#  (21, 'NumCompaniesWorked', 'INT', 0, None, 0),
# ...

# %%
# %%sql
#
# SELECT * from attrition_records;
# Out:
#  * sqlite:///attr_data.db
# Done.
# [(1, 41, 'Yes', 'Travel_Rarely', 1102, 'Sales', 1, 2, 'Life Sciences', 1, 1, 2, 'Female', 94, 3, 2, 'Sales Executive', 4, 'Single', 5993, 19479, 8, 'Y', 'Yes', 11, 3, 1, 80, 0, 8, 0, 1, 6, 4, 0, 5),
#  (2, 49, 'No', 'Travel_Frequently', 279, 'Research & Development', 8, 1, 'Life Sciences', 1, 2, 3, 'Male', 61, 2, 2, 'Research Scientist', 2, 'Married', 5130, 24907, 1, 'Y', 'No', 23, 4, 4, 80, 1, 10, 3, 3, 10, 7, 1, 7),
#  (3, 37, 'Yes', 'Travel_Rarely', 1373, 'Research & Development', 2, 2, 'Other', 1, 4, 4, 'Male', 92, 2, 1, 'Laboratory Technician', 3, 'Single', 2090, 2396, 6, 'Y', 'Yes', 15, 3, 2, 80, 0, 7, 3, 3, 0, 0, 0, 0),
#  (4, 33, 'No', 'Travel_Frequently', 1392, 'Research & Development', 3, 4, 'Life Sciences', 1, 5, 4, 'Female', 56, 3, 1, 'Research Scientist', 3, 'Married', 2909, 23159, 1, 'Y', 'Yes', 11, 3, 3, 80, 0, 8, 3, 3, 8, 7, 3, 0),
# ...

# %%
df = pd.read_sql_table('attrition_records', 'sqlite:///attr_data.db') #extract table from database into pandas dataframe

# %%
df.head()
# Out:
#    id  Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   1   41       Yes      Travel_Rarely       1102                   Sales
# 1   2   49        No  Travel_Frequently        279  Research & Development
# 2   3   37       Yes      Travel_Rarely       1373  Research & Development
# 3   4   33        No  Travel_Frequently       1392  Research & Development
# 4   5   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# 0                 1          2  Life Sciences              1  ...
# 1                 8          1  Life Sciences              1  ...
# 2                 2          2          Other              1  ...
# 3                 3          4  Life Sciences              1  ...
# 4                 2          1        Medical              1  ...
#
#    RelationshipSatisfaction  StandardHours StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 36)

# %%
df.describe()
# Out:
#                 id          Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean    735.500000    36.923810   802.485714          9.192517     2.912925
# std     424.496761     9.135373   403.509100          8.106864     1.024165
# min       1.000000    18.000000   102.000000          1.000000     1.000000
# 25%     368.250000    30.000000   465.000000          2.000000     2.000000
# 50%     735.500000    36.000000   802.000000          7.000000     3.000000
# 75%    1102.750000    43.000000  1157.000000         14.000000     4.000000
# max    1470.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1470 non-null   int64
#  1   Age                       1470 non-null   int64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1470 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1470 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1470 non-null   int64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1470 non-null   object
#  13  HourlyRate                1470 non-null   int64
# ...

# %%
sns.histplot(x='Attrition', data=df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='Count'>

# %%
df.corr()
# Out:
#                                 id       Age  DailyRate  DistanceFromHome  \
# id                        1.000000 -0.010349  -0.051484          0.032928
# Age                      -0.010349  1.000000   0.010661         -0.001686
# DailyRate                -0.051484  0.010661   1.000000         -0.004985
# DistanceFromHome          0.032928 -0.001686  -0.004985          1.000000
# Education                 0.041901  0.208034  -0.016806          0.021042
# EmployeeCount                  NaN       NaN        NaN               NaN
# EmployeeNumber            0.999906 -0.010145  -0.050990          0.032916
# EnvironmentSatisfaction   0.017424  0.010146   0.018355         -0.016075
# HourlyRate                0.034754  0.024287   0.023381          0.031131
# JobInvolvement           -0.007105  0.029820   0.046135          0.008783
# JobLevel                 -0.018041  0.509604   0.002966          0.005303
# JobSatisfaction          -0.045941 -0.004892   0.030571         -0.003669
# ...

# %%
#converting categorical data to numerical
df_2 = df
df_2['Attrition'] = df_2['Attrition'].replace(['Yes', 'No'],
                        [1,0]) #1 reprsents yes and 0 represents no

# %%
df_2.head(10)
# Out:
#    id  Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   1   41          1      Travel_Rarely       1102                   Sales
# 1   2   49          0  Travel_Frequently        279  Research & Development
# 2   3   37          1      Travel_Rarely       1373  Research & Development
# 3   4   33          0  Travel_Frequently       1392  Research & Development
# 4   5   27          0      Travel_Rarely        591  Research & Development
# 5   6   32          0  Travel_Frequently       1005  Research & Development
# 6   7   59          0      Travel_Rarely       1324  Research & Development
# 7   8   30          0      Travel_Rarely       1358  Research & Development
# 8   9   38          0  Travel_Frequently        216  Research & Development
# 9  10   36          0      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# ...

# %% [markdown]
# ## What do you think are the 3 factors behind employee attrition?

# %%
df.corr()
# Out:
#                                 id       Age  Attrition  DailyRate  \
# id                        1.000000 -0.010349  -0.010369  -0.051484
# Age                      -0.010349  1.000000  -0.159205   0.010661
# Attrition                -0.010369 -0.159205   1.000000  -0.056652
# DailyRate                -0.051484  0.010661  -0.056652   1.000000
# DistanceFromHome          0.032928 -0.001686   0.077924  -0.004985
# Education                 0.041901  0.208034  -0.031373  -0.016806
# EmployeeCount                  NaN       NaN        NaN        NaN
# EmployeeNumber            0.999906 -0.010145  -0.010577  -0.050990
# EnvironmentSatisfaction   0.017424  0.010146  -0.103369   0.018355
# HourlyRate                0.034754  0.024287  -0.006846   0.023381
# JobInvolvement           -0.007105  0.029820  -0.130016   0.046135
# JobLevel                 -0.018041  0.509604  -0.169105   0.002966
# JobSatisfaction          -0.045941 -0.004892  -0.103481   0.030571
# ...

# %% [markdown]
# ### from the correlation value we are going to observe
# #### Age
# #### JobLevel
# #### TotalWorkingHours
# #### MonthlyIncome
# #### StockoptionLevel
# #### YearsInCurrentRole
# #### YearsWithCurrManager

# %%
sns.scatterplot(x='Attrition', y='Age', data=df)
plt.show()

# %%
sns.scatterplot(x='Attrition', y='JobLevel', data=df)
plt.show()

# %%
sns.scatterplot(x='Attrition', y='TotalWorkingYears', data=df)
plt.show() 
'''
YearsInCurrentRole and YearsWithCurrManager are closely related with TotalWorkingYears analysis already done
'''

# %%
sns.scatterplot(x='Attrition', y='MonthlyIncome', data=df)
plt.show()

# %%
df[df['MonthlyIncome'] > 15000].value_counts('Attrition')
df[df['MonthlyIncome'] < 15000].value_counts('Attrition')
#attrition drastically reduces above a monthly income of 15000
# Out:
# Attrition
# 0    1105
# 1     232
# dtype: int64

# %%
sns.scatterplot(x='Attrition', y='StockOptionLevel', data=df)
plt.show()

# %% [markdown]
# ## What do you think are the 3 factors behind employee attrition
# ### Answer: From the analysis done above I could safely say
# #### 1. Age
# #### 2. MonthlyIncome
# #### 3. TotalWorkingYears

# %% [markdown]
# ## What is the relationship between Education and Monthly Income?
#
# ### Answer: As shown below monthly income increases with education but the scatter plot and corr value shows there is slight relationship between them

# %%
sns.lineplot(x='Education', y='MonthlyIncome', data=df)
plt.show()

# %%
sns.scatterplot(x='Education', y='MonthlyIncome', data=df)
plt.show()

# %% [markdown]
# ## What is the effect of age on attrition?
#
# ### Answer: After carefully analysing age and attrition I concluded that the older the employee the lower the possibility for attrition

# %%
df[df['Age'] == 60].value_counts('Attrition')
# Out:
# Attrition
# 0    5
# dtype: int64

# %% [markdown]
# ## Is Income the main factor in employee attrition?
# ### Answer: from the analysis below Income is a major factor for employee attrition

# %%
sns.scatterplot(x='Attrition', y='MonthlyIncome', data=df)
plt.show()

# %%
df[df['MonthlyIncome']  < 12.5].value_counts('Attrition')
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## How does work-life balance impact the overall attrition rate?

# %%
df.describe()
# Out:
#                 id          Age    Attrition    DailyRate  DistanceFromHome  \
# count  1470.000000  1470.000000  1470.000000  1470.000000       1470.000000
# mean    735.500000    36.923810     0.161224   802.485714          9.192517
# std     424.496761     9.135373     0.367863   403.509100          8.106864
# min       1.000000    18.000000     0.000000   102.000000          1.000000
# 25%     368.250000    30.000000     0.000000   465.000000          2.000000
# 50%     735.500000    36.000000     0.000000   802.000000          7.000000
# 75%    1102.750000    43.000000     0.000000  1157.000000         14.000000
# max    1470.000000    60.000000     1.000000  1499.000000         29.000000
#
#          Education  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# count  1470.000000         1470.0     1470.000000              1470.000000
# mean      2.912925            1.0     1024.865306                 2.721769
# ...

# %%
df['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
df['WorkLifeBalance'].value_counts('Attrition')
# Out:
# 3    0.607483
# 2    0.234014
# 4    0.104082
# 1    0.054422
# Name: WorkLifeBalance, dtype: float64

# %%
df[df['WorkLifeBalance'] == 1].value_counts('Attrition').mean()
# Out:
# 40.0

# %%
df[df['WorkLifeBalance'] == 2].value_counts('Attrition').mean()
# Out:
# 172.0

# %%
df[df['WorkLifeBalance'] == 3].value_counts('Attrition')
df[df['WorkLifeBalance'] == 3].value_counts('Attrition').mean()
# Out:
# 446.5

# %%
df[df['WorkLifeBalance'] == 4].value_counts('Attrition').mean()
# Out:
# 76.5

# %%
sns.lineplot(x='Attrition', y='WorkLifeBalance', data=df)
plt.show()

# %% [markdown]
# ### Answer: The overall attrition rate increases with worklifebalance then starts decreases
